# %%
# !pip install psycopg2

# %%
import numpy as np
import pandas as pd

import psycopg2   #PostgreSQL database adapter 
from psycopg2.extensions import register_adapter, AsIs 
psycopg2.extensions.register_adapter(np.int64, psycopg2._psycopg.AsIs)
psycopg2.extensions.register_adapter(np.bool_, psycopg2._psycopg.AsIs)

# Connecting to DB
conn = psycopg2.connect(host = "bdaproject.ctixycpwks1a.us-east-1.rds.amazonaws.com", database = "BDAProject", port = "5432", user = "postgres", password = "bdaaiswsa")

cur = conn.cursor() ## Creating a cursor to execute sql commands
cur.execute('''select * from  public."BDA" ''') # sql command to read data
df = cur.fetchall()
conn.commit()
cur.close()
conn.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df
# Out:
# [('US',
#   '49668221',
#   'R2HBOEM8LE9928',
#   'B000068O48',
#   '734576678',
#   'Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor',
#   'Electronics',
#   '5',
#   '0',
#   '0',
#   'N',
#   'Y',
#   'It works as advertising.',
#   'It works as advertising.',
#   '2015-08-31'),
#  ('US',
#   '12338275',
#   'R1P4RW1R9FDPEE',
#   'B000GGKOG8',
#   '614448099',
#   'Channel Master Titan 2 Antenna Preamplifier',
#   'Electronics',
#   '5',
#   '1',
#   '1',
#   'N',
#   'Y',
#   'Five Stars',
#   'Works pissa',
#   '2015-08-31'),
#  ('US',
#   '38487968',
#   'R1EBPM82ENI67M',
#   'B000NU4OTA',
#   '72265257',
#   'LIMTECH Wall charger + USB Hotsync & Charging Dock Cradle desktop Charger for Apple IPOD Shuffle 2nd Generation MP3 Player',
#   'Electronics',
#   '1',
#   '0',
#   '0',
#   'N',
#   'Y',
#   'One Star',
#   'Did not work at all.',
#   '2015-08-31'),
#  ('US',
#   '23732619',
#   'R372S58V6D11AT',
#   'B00JOQIO6S',
#   '308169188',
# ...

# %%
type(df)
# Out:
# list

# %%
#df = pd.DataFrame(df)

# %%
df1 = pd.DataFrame(df, columns =['marketplace', 'customer_id', 'review_id', 'product_id','product_parent','product_tite','product_category','star_rating','helpful_votes','total_votes','vine','verified_purchase','review_headline','review_body','review_date'])

# %%
df1.head()
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 0          US    49668221  R2HBOEM8LE9928  B000068O48      734576678
# 1          US    12338275  R1P4RW1R9FDPEE  B000GGKOG8      614448099
# 2          US    38487968  R1EBPM82ENI67M  B000NU4OTA       72265257
# 3          US    23732619  R372S58V6D11AT  B00JOQIO6S      308169188
# 4          US    21257820  R1A4514XOYI1PD  B008NCD2LG      976385982
#
#                                         product_tite product_category  \
# 0         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 1        Channel Master Titan 2 Antenna Preamplifier      Electronics
# 2  LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 3     Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
# 4  Pioneer SP-BS22-LR Andrew Jones Designed Books...      Electronics
#
#   star_rating helpful_votes total_votes vine verified_purchase  \
# ...

# %%
df1.shape
# Out:
# (3091023, 15)

# %%
df1.drop(['marketplace','customer_id','review_id','product_parent','product_category','helpful_votes','total_votes','vine','verified_purchase'],axis=1)
# Out:
#          product_id                                       product_tite  \
# 0        B000068O48         Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor
# 1        B000GGKOG8        Channel Master Titan 2 Antenna Preamplifier
# 2        B000NU4OTA  LIMTECH Wall charger + USB Hotsync & Charging ...
# 3        B00JOQIO6S     Skullcandy Air Raid Portable Bluetooth Speaker
# 4        B008NCD2LG  Pioneer SP-BS22-LR Andrew Jones Designed Books...
# ...             ...                                                ...
# 3091018  B00000JBAT                         Diamond Rio Digital Player
# 3091019  B00000JBAT                         Diamond Rio Digital Player
# 3091020  B00000J4FY             JVC RVB90 Urban Assault Kaboom (Green)
# 3091021  B00000JHWN                                 Sony DE441 Discman
# 3091022  0966185056  The Sights and Sounds of Christmas: The Comple...
#
#         star_rating                            review_headline  \
# ...

# %%
df1.to_csv('cleaned_dataframe.csv')

# %%
df1 = df = pd.read_csv('clean_data_frame.csv',engine='python')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-9a7c84c23e99> in <module>()
# ----> 1 df1 = df = pd.read_csv('clean_data_frame.csv',engine='python')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
